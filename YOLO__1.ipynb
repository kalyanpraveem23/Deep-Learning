# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17731, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 17731 (delta 51), reused 30 (delta 29), pack-reused 17642 (from 3)
# Receiving objects: 100% (17731/17731), 17.16 MiB | 18.57 MiB/s, done.
# Resolving deltas: 100% (12043/12043), done.

# %%
# %cd
# Out:
# /root

# %%
#/content/yolov5

# %% [markdown]
# # **Step 2: Change directory to yolov5**

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %% [markdown]
# # **Step 3: Install the dependencies**

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Step 4: Run Object Detection on Images. Provide the Image Path**

# %%
# !python detect.py --weights yolov5n.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# detect: weights=['yolov5n.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-447-ge76591cb Python-3.12.12 torch-2.8.0+cu126 CPU
#
# ...
# 100% 3.87M/3.87M [00:00<00:00, 58.7MB/s]
#
# Fusing layers...
# ...

# %%
# !python detect.py --weights yolov5n.pt --source /content/cric.jpg
# Out:
# detect: weights=['yolov5n.pt'], source=/content/cric.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-447-ge76591cb Python-3.12.12 torch-2.8.0+cu126 CPU
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# image 1/1 /content/cric.jpg: 384x640 11 persons, 164.2ms
# Speed: 7.8ms pre-process, 164.2ms inference, 2.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3
